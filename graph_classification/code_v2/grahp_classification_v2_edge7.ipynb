# %% [markdown]
# Biblioteki

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from PIL import Image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from keras.callbacks import ReduceLROnPlateau
import shutil
from sklearn.model_selection import train_test_split

# %% [markdown]
# Ścieżki i wstępne ustawienia

# %%
# Ścieżka do katalogu z obrazami
edge_count = '7' # tu do zmiany liczba wierzchołków do nauki modelu
data_dir_generated = '../graph_generator/' + edge_count
data_dir_model = 'graphs'
train_dir = os.path.join(data_dir_model, 'train')
validation_dir = os.path.join(data_dir_model, 'validation')

# Sprawdź, czy katalogi istnieją, jeśli nie, stwórz je
for directory in [data_dir_model, train_dir, validation_dir]:
    if not os.path.exists(directory):
        os.makedirs(directory)

# Wielkość obrazów i wielkość partii
img_height, img_width = 180, 180
batch_size = 32

# %% [markdown]
# Przenoszenie do katalogów

# %%
# Pobierz listę wszystkich katalogów z grafami
all_images_catalogs = os.listdir(data_dir_generated)

for catalog in all_images_catalogs:
    catalog_path = os.path.join(data_dir_generated, catalog)
    all_images = os.listdir(catalog_path)

    # Podziel listę obrazów na zestawy treningowe i walidacyjne
    train_images, validation_images = train_test_split(all_images, test_size=0.2, random_state=42)

    # Stwórz katalogi dla każdej klasy
    train_class_dir = os.path.join(train_dir, catalog)
    validation_class_dir = os.path.join(validation_dir, catalog)
    for directory in [train_class_dir, validation_class_dir]:
        if not os.path.exists(directory):
            os.makedirs(directory)
        else:
            # Jeśli katalog nie jest pusty, wyczyść go
            for file in os.listdir(directory):
                os.remove(os.path.join(directory, file))

    # Kopiuj obrazy do odpowiednich katalogów
    for train_image in train_images:
        shutil.copy(os.path.join(catalog_path, train_image), os.path.join(train_class_dir, train_image))

    for validation_image in validation_images:
        shutil.copy(os.path.join(catalog_path, validation_image), os.path.join(validation_class_dir, validation_image))

# %%
def rgb_to_grayscale(images):
    return tf.image.rgb_to_grayscale(images)

# %% [markdown]
# Model

# %%
# Generowanie danych treningowych
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  train_dir,
  image_size=(img_height, img_width),
  batch_size=batch_size)

class_names = train_ds.class_names

train_ds = train_ds.map(lambda x, y: (rgb_to_grayscale(x), y))

# Generowanie danych walidacyjnych
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  validation_dir,
  image_size=(img_height, img_width),
  batch_size=batch_size)

val_ds = val_ds.map(lambda x, y: (rgb_to_grayscale(x), y))

# Tworzenie modelu
model = tf.keras.models.Sequential([
  tf.keras.layers.Rescaling(1./255),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01)),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(len(class_names))
])
# Out:
# Found 2000 files belonging to 5 classes.
# Found 500 files belonging to 5 classes.

# %%
# Kompilacja modelu
model.compile(
  optimizer='adam',
  loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])

# Trenowanie modelu
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=75
)
# Out:
# Epoch 1/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 11s 155ms/step - accuracy: 0.4098 - loss: 2.2985 - val_accuracy: 0.9440 - val_loss: 0.4055
# Epoch 2/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 133ms/step - accuracy: 0.9605 - loss: 0.3325 - val_accuracy: 0.9880 - val_loss: 0.1669
# Epoch 3/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9766 - loss: 0.1957 - val_accuracy: 0.9560 - val_loss: 0.2575
# Epoch 4/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 130ms/step - accuracy: 0.9754 - loss: 0.2568 - val_accuracy: 0.9840 - val_loss: 0.1583
# Epoch 5/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9837 - loss: 0.1517 - val_accuracy: 0.9820 - val_loss: 0.1668
# Epoch 6/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 130ms/step - accuracy: 0.9882 - loss: 0.1513 - val_accuracy: 0.9920 - val_loss: 0.1862
# Epoch 7/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 130ms/step - accuracy: 0.9819 - loss: 0.2083 - val_accuracy: 0.9760 - val_loss: 0.2563
# Epoch 8/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 130ms/step - accuracy: 0.9760 - loss: 0.2617 - val_accuracy: 0.9900 - val_loss: 0.1469
# Epoch 9/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 130ms/step - accuracy: 0.9976 - loss: 0.1121 - val_accuracy: 0.9920 - val_loss: 0.1173
# Epoch 10/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 130ms/step - accuracy: 0.9906 - loss: 0.1340 - val_accuracy: 0.9860 - val_loss: 0.1295
# Epoch 11/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 129ms/step - accuracy: 0.9847 - loss: 0.1166 - val_accuracy: 0.9660 - val_loss: 0.1937
# Epoch 12/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.9723 - loss: 0.2107 - val_accuracy: 0.9880 - val_loss: 0.1394
# Epoch 13/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 129ms/step - accuracy: 0.9918 - loss: 0.1252 - val_accuracy: 0.9800 - val_loss: 0.1550
# Epoch 14/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 129ms/step - accuracy: 0.9944 - loss: 0.1285 - val_accuracy: 0.9920 - val_loss: 0.1000
# Epoch 15/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 130ms/step - accuracy: 0.9974 - loss: 0.0793 - val_accuracy: 0.9940 - val_loss: 0.0701
# Epoch 16/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 129ms/step - accuracy: 0.9952 - loss: 0.0620 - val_accuracy: 0.9560 - val_loss: 0.2354
# Epoch 17/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 130ms/step - accuracy: 0.9642 - loss: 0.2230 - val_accuracy: 0.9840 - val_loss: 0.2022
# Epoch 18/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 129ms/step - accuracy: 0.9959 - loss: 0.1599 - val_accuracy: 0.9880 - val_loss: 0.1023
# Epoch 19/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 129ms/step - accuracy: 0.9987 - loss: 0.0784 - val_accuracy: 0.9920 - val_loss: 0.0731
# Epoch 20/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 129ms/step - accuracy: 0.9934 - loss: 0.0663 - val_accuracy: 0.9900 - val_loss: 0.0782
# Epoch 21/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 127ms/step - accuracy: 0.9945 - loss: 0.0633 - val_accuracy: 0.9840 - val_loss: 0.0898
# Epoch 22/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 126ms/step - accuracy: 0.9921 - loss: 0.0820 - val_accuracy: 0.9880 - val_loss: 0.1001
# Epoch 23/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 129ms/step - accuracy: 0.9943 - loss: 0.0851 - val_accuracy: 0.9880 - val_loss: 0.0853
# Epoch 24/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 126ms/step - accuracy: 0.9979 - loss: 0.0590 - val_accuracy: 0.6940 - val_loss: 1.0511
# Epoch 25/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 127ms/step - accuracy: 0.8480 - loss: 0.6379 - val_accuracy: 0.9860 - val_loss: 0.1479
# Epoch 26/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 126ms/step - accuracy: 0.9926 - loss: 0.1175 - val_accuracy: 0.9860 - val_loss: 0.1085
# Epoch 27/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 127ms/step - accuracy: 0.9969 - loss: 0.0793 - val_accuracy: 0.9900 - val_loss: 0.0778
# Epoch 28/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 126ms/step - accuracy: 0.9971 - loss: 0.0603 - val_accuracy: 0.9940 - val_loss: 0.0594
# Epoch 29/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 127ms/step - accuracy: 0.9961 - loss: 0.0536 - val_accuracy: 0.9920 - val_loss: 0.0580
# Epoch 30/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 126ms/step - accuracy: 0.9992 - loss: 0.0449 - val_accuracy: 0.9960 - val_loss: 0.0470
# Epoch 31/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 126ms/step - accuracy: 0.9979 - loss: 0.0384 - val_accuracy: 0.9900 - val_loss: 0.0442
# Epoch 32/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 126ms/step - accuracy: 0.9980 - loss: 0.0340 - val_accuracy: 0.9840 - val_loss: 0.0848
# Epoch 33/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 126ms/step - accuracy: 0.9877 - loss: 0.0761 - val_accuracy: 0.9600 - val_loss: 0.1591
# Epoch 34/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 129ms/step - accuracy: 0.9816 - loss: 0.1122 - val_accuracy: 0.9840 - val_loss: 0.0917
# Epoch 35/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 126ms/step - accuracy: 0.9963 - loss: 0.0698 - val_accuracy: 0.9900 - val_loss: 0.0660
# Epoch 36/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 126ms/step - accuracy: 0.9982 - loss: 0.0496 - val_accuracy: 0.9900 - val_loss: 0.0721
# Epoch 37/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 127ms/step - accuracy: 0.9992 - loss: 0.0469 - val_accuracy: 0.9860 - val_loss: 0.0671
# Epoch 38/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 127ms/step - accuracy: 0.9996 - loss: 0.0379 - val_accuracy: 0.9900 - val_loss: 0.0498
# Epoch 39/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 127ms/step - accuracy: 0.9991 - loss: 0.0341 - val_accuracy: 0.9880 - val_loss: 0.0559
# Epoch 40/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 126ms/step - accuracy: 0.9989 - loss: 0.0321 - val_accuracy: 0.9260 - val_loss: 0.2143
# Epoch 41/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 126ms/step - accuracy: 0.9741 - loss: 0.1336 - val_accuracy: 0.9820 - val_loss: 0.1073
# Epoch 42/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9972 - loss: 0.0700 - val_accuracy: 0.9880 - val_loss: 0.0717
# Epoch 43/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 126ms/step - accuracy: 0.9974 - loss: 0.0502 - val_accuracy: 0.9940 - val_loss: 0.0527
# Epoch 44/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 127ms/step - accuracy: 0.9998 - loss: 0.0375 - val_accuracy: 0.9900 - val_loss: 0.0630
# Epoch 45/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 128ms/step - accuracy: 1.0000 - loss: 0.0327 - val_accuracy: 0.9980 - val_loss: 0.0376
# Epoch 46/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 127ms/step - accuracy: 1.0000 - loss: 0.0275 - val_accuracy: 0.9920 - val_loss: 0.0553
# Epoch 47/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 127ms/step - accuracy: 0.9942 - loss: 0.0375 - val_accuracy: 0.8920 - val_loss: 0.3896
# Epoch 48/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 126ms/step - accuracy: 0.9497 - loss: 0.2450 - val_accuracy: 0.9940 - val_loss: 0.1027
# Epoch 49/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 127ms/step - accuracy: 0.9943 - loss: 0.0946 - val_accuracy: 0.9880 - val_loss: 0.0971
# Epoch 50/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 127ms/step - accuracy: 0.9977 - loss: 0.0680 - val_accuracy: 0.9960 - val_loss: 0.0669
# Epoch 51/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 127ms/step - accuracy: 0.9955 - loss: 0.0758 - val_accuracy: 0.9860 - val_loss: 0.0876
# Epoch 52/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 126ms/step - accuracy: 0.9995 - loss: 0.0544 - val_accuracy: 0.9940 - val_loss: 0.0613
# Epoch 53/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 127ms/step - accuracy: 0.9972 - loss: 0.0465 - val_accuracy: 0.9940 - val_loss: 0.0490
# Epoch 54/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 126ms/step - accuracy: 1.0000 - loss: 0.0348 - val_accuracy: 0.9940 - val_loss: 0.0418
# Epoch 55/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 126ms/step - accuracy: 0.9995 - loss: 0.0297 - val_accuracy: 0.9920 - val_loss: 0.0470
# Epoch 56/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 130ms/step - accuracy: 0.9993 - loss: 0.0311 - val_accuracy: 0.9900 - val_loss: 0.0478
# Epoch 57/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 127ms/step - accuracy: 0.9972 - loss: 0.0350 - val_accuracy: 0.9920 - val_loss: 0.0510
# Epoch 58/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 127ms/step - accuracy: 0.9902 - loss: 0.0636 - val_accuracy: 0.9860 - val_loss: 0.0780
# Epoch 59/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 127ms/step - accuracy: 0.9940 - loss: 0.0671 - val_accuracy: 0.9940 - val_loss: 0.0626
# Epoch 60/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 127ms/step - accuracy: 0.9996 - loss: 0.0488 - val_accuracy: 0.9880 - val_loss: 0.0625
# Epoch 61/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 127ms/step - accuracy: 0.9967 - loss: 0.0482 - val_accuracy: 0.9920 - val_loss: 0.0491
# Epoch 62/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 127ms/step - accuracy: 0.9997 - loss: 0.0377 - val_accuracy: 0.9920 - val_loss: 0.0506
# Epoch 63/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 127ms/step - accuracy: 0.9967 - loss: 0.0376 - val_accuracy: 0.9920 - val_loss: 0.0450
# Epoch 64/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 126ms/step - accuracy: 1.0000 - loss: 0.0298 - val_accuracy: 0.9940 - val_loss: 0.0396
# Epoch 65/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 127ms/step - accuracy: 0.9995 - loss: 0.0266 - val_accuracy: 0.9880 - val_loss: 0.0470
# Epoch 66/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 127ms/step - accuracy: 0.9996 - loss: 0.0248 - val_accuracy: 0.9820 - val_loss: 0.0805
# Epoch 67/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 126ms/step - accuracy: 0.9940 - loss: 0.0401 - val_accuracy: 0.9880 - val_loss: 0.0618
# Epoch 68/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 127ms/step - accuracy: 0.9940 - loss: 0.0516 - val_accuracy: 0.9920 - val_loss: 0.0633
# Epoch 69/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 126ms/step - accuracy: 0.9970 - loss: 0.0494 - val_accuracy: 0.9800 - val_loss: 0.0795
# Epoch 70/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 127ms/step - accuracy: 0.9978 - loss: 0.0454 - val_accuracy: 0.9820 - val_loss: 0.0885
# Epoch 71/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 127ms/step - accuracy: 0.9914 - loss: 0.0748 - val_accuracy: 0.9880 - val_loss: 0.0876
# Epoch 72/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 127ms/step - accuracy: 0.9962 - loss: 0.0548 - val_accuracy: 0.9900 - val_loss: 0.0644
# Epoch 73/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 127ms/step - accuracy: 0.9985 - loss: 0.0419 - val_accuracy: 0.9880 - val_loss: 0.0567
# Epoch 74/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 127ms/step - accuracy: 0.9977 - loss: 0.0398 - val_accuracy: 0.9900 - val_loss: 0.0515
# Epoch 75/75
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 127ms/step - accuracy: 1.0000 - loss: 0.0288 - val_accuracy: 0.9840 - val_loss: 0.0597

# %%
# Wyświetlanie dokładności na zbiorze treningowym i walidacyjnym
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
print("Dokładność na zbiorze treningowym: ", acc)
print("Dokładność na zbiorze walidacyjnym: ", val_acc)
# Out:
# Dokładność na zbiorze treningowym:  [0.6499999761581421, 0.9725000262260437, 0.9714999794960022, 0.9850000143051147, 0.9829999804496765, 0.9835000038146973, 0.9760000109672546, 0.9850000143051147, 0.9919999837875366, 0.9915000200271606, 0.9810000061988831, 0.9825000166893005, 0.9854999780654907, 0.9929999709129333, 0.9959999918937683, 0.9865000247955322, 0.9714999794960022, 0.9959999918937683, 0.9975000023841858, 0.9940000176429749, 0.9944999814033508, 0.9904999732971191, 0.9934999942779541, 0.9965000152587891, 0.921999990940094, 0.9944999814033508, 0.9980000257492065, 0.9965000152587891, 0.9965000152587891, 0.9990000128746033, 0.9990000128746033, 0.996999979019165, 0.9919999837875366, 0.987500011920929, 0.996999979019165, 0.996999979019165, 0.9980000257492065, 0.9990000128746033, 0.9984999895095825, 0.9940000176429749, 0.9835000038146973, 0.9980000257492065, 0.9990000128746033, 0.9994999766349792, 1.0, 0.9994999766349792, 0.9819999933242798, 0.9674999713897705, 0.9925000071525574, 0.9944999814033508, 0.9955000281333923, 0.9994999766349792, 0.9984999895095825, 0.9994999766349792, 0.9984999895095825, 0.9980000257492065, 0.9944999814033508, 0.9869999885559082, 0.9950000047683716, 0.9990000128746033, 0.9965000152587891, 0.9990000128746033, 0.9984999895095825, 1.0, 0.9994999766349792, 0.9990000128746033, 0.9919999837875366, 0.9944999814033508, 0.9959999918937683, 0.9955000281333923, 0.9934999942779541, 0.9975000023841858, 0.9975000023841858, 0.9994999766349792, 1.0]
# Dokładność na zbiorze walidacyjnym:  [0.9440000057220459, 0.9879999756813049, 0.9559999704360962, 0.984000027179718, 0.9819999933242798, 0.9919999837875366, 0.9760000109672546, 0.9900000095367432, 0.9919999837875366, 0.9860000014305115, 0.9660000205039978, 0.9879999756813049, 0.9800000190734863, 0.9919999837875366, 0.9940000176429749, 0.9559999704360962, 0.984000027179718, 0.9879999756813049, 0.9919999837875366, 0.9900000095367432, 0.984000027179718, 0.9879999756813049, 0.9879999756813049, 0.6940000057220459, 0.9860000014305115, 0.9860000014305115, 0.9900000095367432, 0.9940000176429749, 0.9919999837875366, 0.9959999918937683, 0.9900000095367432, 0.984000027179718, 0.9599999785423279, 0.984000027179718, 0.9900000095367432, 0.9900000095367432, 0.9860000014305115, 0.9900000095367432, 0.9879999756813049, 0.9259999990463257, 0.9819999933242798, 0.9879999756813049, 0.9940000176429749, 0.9900000095367432, 0.9980000257492065, 0.9919999837875366, 0.8920000195503235, 0.9940000176429749, 0.9879999756813049, 0.9959999918937683, 0.9860000014305115, 0.9940000176429749, 0.9940000176429749, 0.9940000176429749, 0.9919999837875366, 0.9900000095367432, 0.9919999837875366, 0.9860000014305115, 0.9940000176429749, 0.9879999756813049, 0.9919999837875366, 0.9919999837875366, 0.9919999837875366, 0.9940000176429749, 0.9879999756813049, 0.9819999933242798, 0.9879999756813049, 0.9919999837875366, 0.9800000190734863, 0.9819999933242798, 0.9879999756813049, 0.9900000095367432, 0.9879999756813049, 0.9900000095367432, 0.984000027179718]

# %%
# Wykres dokładności
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Dokładność (trening)')
plt.plot(history.history['val_accuracy'], label='Dokładność (walidacja)')
plt.legend(loc='lower right')
plt.title('Dokładność modelu')
plt.ylabel('Dokładność')
plt.xlabel('Epoka')

# Wykres straty
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Strata (trening)')
plt.plot(history.history['val_loss'], label='Strata (walidacja)')
plt.legend(loc='upper right')
plt.title('Strata modelu')
plt.ylabel('Strata')
plt.xlabel('Epoka')

plt.show()

# %%
def get_image_filenames(folder):
    filenames = []
    for filename in os.listdir(folder):
        if filename.endswith(".jpg") or filename.endswith(".png"): # Add or modify to suit your image file types
            filenames.append(filename)
    return filenames

# %%
# Zmieniamy funkcję, aby przeszukiwała również podkatalogi
def get_image_filenames(directory):
    return [os.path.join(root, name)
            for root, dirs, files in os.walk(directory)
            for name in files
            if name.endswith((".png", ".jpg", ".jpeg"))]

# Ścieżka do obrazu, który chcesz przetestować
test_photo_path = 'test_graphs'

test_photos = get_image_filenames(test_photo_path)
test_photos
# Out:
# ['test_graphs\\drawn\\connected-drawn-1.png',
#  'test_graphs\\drawn\\cycle-drawn-1.png',
#  'test_graphs\\drawn\\full-drawn-1.jpg',
#  'test_graphs\\drawn\\full-drawn-2.jpg',
#  'test_graphs\\drawn\\full-drawn-3.png',
#  'test_graphs\\drawn\\path-drawn-1.png',
#  'test_graphs\\drawn\\path-drawn-2.png',
#  'test_graphs\\drawn\\path-drawn-3.png',
#  'test_graphs\\generated\\cycle-45.png',
#  'test_graphs\\generated\\full-113.png',
#  'test_graphs\\generated\\path-78.png',
#  'test_graphs\\internet\\internet-cycle-1.png',
#  'test_graphs\\internet\\internet-full-1.jpg',
#  'test_graphs\\internet\\internet-full-2.jpg']

# %%
for test_photo in test_photos:
    # Wybór obrazka testowego
    image_path = test_photo

    # Wczytanie obrazu i dostosowanie go do odpowiedniego rozmiaru
    img = tf.keras.preprocessing.image.load_img(image_path, target_size=(img_height, img_width))
    img_array = tf.keras.preprocessing.image.img_to_array(img)
    
    # Przekształć obraz do skali szarości
    img_array = rgb_to_grayscale(img_array)
    # Rozszerz wymiary obrazu
    img_array = tf.expand_dims(img_array, 0)

    # Przewidywanie klasy obrazu
    predictions = model.predict(img_array)
    score = tf.nn.softmax(predictions[0])

    print(
        "|- {} -| najprawdopodobniej należy do klasy |- {} -| z prawdopodobieństwem {:.2f} procent."
        .format(test_photo, class_names[np.argmax(score)], 100 * np.max(score))
    )
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# |- test_graphs\drawn\connected-drawn-1.png -| najprawdopodobniej należy do klasy |- full -| z prawdopodobieństwem 99.90 procent.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# |- test_graphs\drawn\cycle-drawn-1.png -| najprawdopodobniej należy do klasy |- full -| z prawdopodobieństwem 99.98 procent.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# |- test_graphs\drawn\full-drawn-1.jpg -| najprawdopodobniej należy do klasy |- full -| z prawdopodobieństwem 99.96 procent.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# |- test_graphs\drawn\full-drawn-2.jpg -| najprawdopodobniej należy do klasy |- full -| z prawdopodobieństwem 99.99 procent.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# |- test_graphs\drawn\full-drawn-3.png -| najprawdopodobniej należy do klasy |- full -| z prawdopodobieństwem 100.00 procent.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# |- test_graphs\drawn\path-drawn-1.png -| najprawdopodobniej należy do klasy |- full -| z prawdopodobieństwem 99.65 procent.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# |- test_graphs\drawn\path-drawn-2.png -| najprawdopodobniej należy do klasy |- full -| z prawdopodobieństwem 99.36 procent.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# |- test_graphs\drawn\path-drawn-3.png -| najprawdopodobniej należy do klasy |- full -| z prawdopodobieństwem 72.79 procent.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# |- test_graphs\generated\cycle-45.png -| najprawdopodobniej należy do klasy |- cycle -| z prawdopodobieństwem 99.33 procent.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# |- test_graphs\generated\full-113.png -| najprawdopodobniej należy do klasy |- full -| z prawdopodobieństwem 99.84 procent.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# |- test_graphs\generated\path-78.png -| najprawdopodobniej należy do klasy |- path -| z prawdopodobieństwem 99.99 procent.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# |- test_graphs\internet\internet-cycle-1.png -| najprawdopodobniej należy do klasy |- cycle -| z prawdopodobieństwem 100.00 procent.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# |- test_graphs\internet\internet-full-1.jpg -| najprawdopodobniej należy do klasy |- full -| z prawdopodobieństwem 95.10 procent.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# |- test_graphs\internet\internet-full-2.jpg -| najprawdopodobniej należy do klasy |- full -| z prawdopodobieństwem 96.11 procent.
